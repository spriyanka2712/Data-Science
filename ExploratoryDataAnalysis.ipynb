# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("student_data.csv")

# %%
print("First 5 Rows")
print(df.head())
# Out:
# First 5 Rows
#    Student_ID  Age  Gender  Attendance  Marks
# 0           1   18  Female        90.0   85.0
# 1           2   19    Male        85.0   78.0
# 2           3   20  Female         NaN   92.0
# 3           4   18    Male        88.0   76.0
# 4           5   21  Female        95.0   89.0

# %%
print("\nDataset Shape")
print(df.shape)
# Out:
# Dataset Shape
# (16, 5)

# %%
print("\nColumn Information")
print(df.info())
# Out:
# Column Information
# <class 'pandas.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Student_ID  16 non-null     int64
#  1   Age         16 non-null     int64
#  2   Gender      16 non-null     str
#  3   Attendance  14 non-null     float64
#  4   Marks       15 non-null     float64
# dtypes: float64(2), int64(2), str(1)
# memory usage: 772.0 bytes
# None

# %%
print("\nStatistical Summary")
print(df.describe())
# Out:
# Statistical Summary
#        Student_ID        Age  Attendance       Marks
# count   16.000000  16.000000   14.000000   15.000000
# mean     7.875000  19.437500   90.142857   97.533333
# std      4.349329   1.209339    3.997252   56.306390
# min      1.000000  18.000000   85.000000   76.000000
# 25%      4.750000  18.750000   87.250000   78.000000
# 50%      7.500000  19.000000   90.000000   82.000000
# 75%     11.250000  20.000000   92.750000   88.500000
# max     15.000000  22.000000   98.000000  300.000000

# %%
print("\nMissing Values")
print(df.isnull().sum())
# Out:
# Missing Values
# Student_ID    0
# Age           0
# Gender        0
# Attendance    2
# Marks         1
# dtype: int64

# %%
df['Attendance'] = df['Attendance'].fillna(df['Attendance'].mean())
df['Marks'] = df['Marks'].fillna(df['Marks'].mean())

# %%
df = df.drop_duplicates()

# %%
df['Gender'].value_counts().plot(kind='bar')
plt.title("Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()

# %%
plt.hist(df['Marks'], bins=5)
plt.title("Marks Distribution")
plt.xlabel("Marks")
plt.ylabel("Frequency")
plt.show()

# %%
plt.scatter(df['Attendance'], df['Marks'])
plt.title("Attendance vs Marks")
plt.xlabel("Attendance")
plt.ylabel("Marks")
plt.show()

# %%
numeric_df = df[['Age', 'Attendance', 'Marks']]
corr = numeric_df.corr()
print("\nCorrelation Matrix")
print(corr)
# Out:
# Correlation Matrix
#                  Age  Attendance     Marks
# Age         1.000000    0.762095  0.626689
# Attendance  0.762095    1.000000  0.635667
# Marks       0.626689    0.635667  1.000000

# %%
plt.imshow(corr, cmap='coolwarm')
plt.colorbar()
plt.xticks(range(len(corr.columns)), corr.columns)
plt.yticks(range(len(corr.columns)), corr.columns)
plt.title("Correlation Heatmap")
plt.show()
